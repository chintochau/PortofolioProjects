# %%
import pandas as pd
import numpy as np
import missingno as msno
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import datetime
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import chi2_contingency
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
#Import data set
df = pd.read_csv('netflix_titles.csv')
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
## change date format
df['date_added'] = pd.to_datetime(df['date_added'])
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#   date_added  release_year rating   duration  \
# 0 2021-09-25          2020  PG-13     90 min
# 1 2021-09-24          2021  TV-MA  2 Seasons
# 2 2021-09-24          2021  TV-MA   1 Season
# ...

# %% [markdown]
# ## High Level EDA

# %%
df.dtypes
# Out:
# show_id                 object
# type                    object
# title                   object
# director                object
# cast                    object
# country                 object
# date_added      datetime64[ns]
# release_year             int64
# rating                  object
# duration                object
# listed_in               object
# description             object
# dtype: object

# %%
# check missing values
msno.matrix(df)
msno.heatmap(df)
# Out:
# <AxesSubplot:>
# <AxesSubplot:>

# %% [markdown]
# ## Numerical describe

# %%
df.describe()
# Out:
#        release_year
# count   8807.000000
# mean    2014.180198
# std        8.819312
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %% [markdown]
# ## Date Analysis

# %%
fig = px.histogram(df,x='release_year' )
fig.update_layout(bargap=0.05)

# %%
# look at the interesting data with release date 1925
df[df['release_year'] == 1925]
## showing full length
with pd.option_context('display.max_colwidth', None):
    df[df['release_year'] == 1925]
# Out:
#      show_id     type                              title director cast  \
# 4250   s4251  TV Show  Pioneers: First Women Filmmakers*      NaN  NaN
#
#      country date_added  release_year rating  duration listed_in  \
# 4250     NaN 2018-12-30          1925  TV-14  1 Season  TV Shows
#
#                                             description
# 4250  This collection restores films from women who ...
#      show_id     type                              title director cast  \
# 4250   s4251  TV Show  Pioneers: First Women Filmmakers*      NaN  NaN
#
#      country date_added  release_year rating  duration listed_in  \
# 4250     NaN 2018-12-30          1925  TV-14  1 Season  TV Shows
#
#                                                                                                                                                  description
# ...

# %%
fig = px.histogram(df,x='date_added' )
fig.update_layout(bargap=0.05)

# %%
## Extract month from date_added
df['date_added_month'] = df['date_added'].dt.month.fillna(0)
df.sort_values(by=['date_added_month'])
# Out:
#      show_id     type                                        title  \
# 6066   s6067  TV Show  A Young Doctor's Notebook and Other Stories
# 7254   s7255  TV Show                          La Familia P. Luche
# 7847   s7848  TV Show                                 Red vs. Blue
# 6806   s6807  TV Show                                      Friends
# 7406   s7407  TV Show                                        Maron
# ...      ...      ...                                          ...
# 3107   s3108    Movie                               Jacob's Ladder
# 6783   s6784    Movie    Forbidden Games: The Justin Fashanu Story
# 6782   s6783  TV Show                                  For the Win
# 3092   s3093  TV Show               Kevin Hart: Don’t F**k This Up
# 8332   s8333    Movie                            The Great Gambler
#
#                    director  \
# 6066                    NaN
# 7254                    NaN
# 7847                    NaN
# 6806                    NaN
# ...

# %%
fig = px.histogram(df,x='date_added',color='date_added_month' )
fig.update_layout(bargap=0.05)
fig1 = px.histogram(df,x='date_added_month' )
fig1.update_layout(bargap=0.05)

# %%
## Extract day from date_added
df['date_added_day'] = df['date_added'].dt.day.fillna(0)
fig = px.histogram(df,x='date_added_day')
fig.update_layout(bargap=0.05)
# looks like Netflix adds movie on the first of the month more than the other days

# %% [markdown]
# ## String Column Analysis

# %%
list(df.columns)
# Out:
# ['show_id',
#  'type',
#  'title',
#  'director',
#  'cast',
#  'country',
#  'date_added',
#  'release_year',
#  'rating',
#  'duration',
#  'listed_in',
#  'description',
#  'date_added_month',
#  'date_added_day']

# %%
df['type'].unique()
df['type'].hist()
# Out:
# array(['Movie', 'TV Show'], dtype=object)
# <AxesSubplot:>

# %%
df['country'].unique()
#seems it is showing the collections of countries
# Out:
# array(['United States', 'South Africa', nan, 'India',
#        'United States, Ghana, Burkina Faso, United Kingdom, Germany, Ethiopia',
#        'United Kingdom', 'Germany, Czech Republic', 'Mexico', 'Turkey',
#        'Australia', 'United States, India, France', 'Finland',
#        'China, Canada, United States',
#        'South Africa, United States, Japan', 'Nigeria', 'Japan',
#        'Spain, United States', 'France', 'Belgium',
#        'United Kingdom, United States', 'United States, United Kingdom',
#        'France, United States', 'South Korea', 'Spain',
#        'United States, Singapore', 'United Kingdom, Australia, France',
#        'United Kingdom, Australia, France, United States',
#        'United States, Canada', 'Germany, United States',
#        'South Africa, United States', 'United States, Mexico',
#        'United States, Italy, France, Japan',
#        'United States, Italy, Romania, United Kingdom',
#        'Australia, United States', 'Argentina, Venezuela',
# ...

# %%
df
df['country'].str.split(',',expand=True)
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
# create a new df
country_count = df.copy()
country_count = pd.concat([country_count, df['country'].str.split(',',expand=True)],axis=1)
country_count
country_count = country_count.melt(id_vars=['title','type'],value_vars=range(12)).dropna(subset='value').reset_index(drop=True).rename(columns={'value':'country'})
country_count
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
px.histogram(country_count,'country')
#seems the data is dirty, some countries shows in different columns

# %%
country_count['country'] = country_count['country'].str.strip()
px.histogram(country_count,'country',color='type').update_xaxes(categoryorder='total descending')

# %%
df['rating'].value_counts()
px.histogram(df, 'rating',color='type').update_xaxes(categoryorder='total descending')
# Out:
# TV-MA       3207
# TV-14       2160
# TV-PG        863
# R            799
# PG-13        490
# TV-Y7        334
# TV-Y         307
# PG           287
# TV-G         220
# NR            80
# G             41
# TV-Y7-FV       6
# NC-17          3
# UR             3
# 74 min         1
# 84 min         1
# 66 min         1
# Name: rating, dtype: int64

# %%
df['cast_count'] = df['cast'].str.split(',')
df = df[df['cast_count'].notna()]
df['cast_count'] = df['cast_count'].apply(lambda x:len(x))
df
# Out:
# C:\Users\Jason Chau\AppData\Local\Temp\ipykernel_3304\3433451744.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#      show_id     type                             title  \
# 1         s2  TV Show                     Blood & Water
# 2         s3  TV Show                         Ganglands
# 4         s5  TV Show                      Kota Factory
# 5         s6  TV Show                     Midnight Mass
# 6         s7    Movie  My Little Pony: A New Generation
# ...      ...      ...                               ...
# 8801   s8802    Movie                           Zinzana
# 8802   s8803    Movie                            Zodiac
# 8804   s8805    Movie                        Zombieland
# ...

# %%
px.histogram(df,'cast_count').update_layout(bargap=0.05)
